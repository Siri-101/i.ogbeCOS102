# %%
import pandas as pd

girls_name = ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"]
girls_age = [17,16,17,18,16,18,17,20,19,17]
girls_score = [80,85,70,60,76,66,87,95,50,49]
girls_height = [5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5]

boys_name = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas","Wesley"]
boys_age = [19,16,18,17,20,19,16,18,17,19]
boys_height = [5.7,5.9,5.8,6.1,5.9,5.5,61,5.4,5.8,5.7]
boys_score = [74,87,75,68,66,78,87,98,54,60]


girls_table = pd.DataFrame({
    "Name": girls_name,
    "Age": girls_age,
    "Score": girls_score,
    "Height": girls_height,

})

boys_table: pd.DataFrame({
    "Name": boys_name,
    "Age": boys_age,
    "Score": boys_score,
    "Height": boys_height,

})

print(girls_table)
print(boys_table)
# Out:
#       Name  Age  Score  Height
# 0   Evelyn   17     80     5.5
# 1  Jessica   16     85     6.0
# 2    Somto   17     70     5.4
# 3    Edith   18     60     5.9
# 4     Liza   16     76     5.6
# 5  Madonna   18     66     5.5
# 6     Waje   17     87     6.1
# 7     Tola   20     95     6.0
# 8    Aisha   19     50     5.7
# 9   Latifa   17     49     5.5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 31
#      22 boys_table: pd.DataFrame({
#      23     "Name": boys_name,
#      24     "Age": boys_age,
#    (...)     27
#      28 })
#      30 print(girls_table)
# ---> 31 print(boys_table)
#
# NameError: name 'boys_table' is not defined
