# %% [markdown]
# BEGIN
#     TAKE goods
#     COLLECT receipt
#     CHECK receipt by security guard
#     EXIT store
# END
# ![Screenshot 2026-03-11 151225.png](attachment:f1168fe8-1c20-4fd5-8883-5d86711a48f9.png)

# %% [markdown]
# ![Screenshot 2026-03-11 151225.png](attachment:a7ad5e1a-68e1-4a29-845c-dc3f10f55224.png

# %% [markdown]
# BEGIN
#     WAKE UP
#     STAND UP
#     ENTER bathroom
#     BATHE
#     BRUSH teeth
#     COME OUT of bathroom
#     WEAR clothes
#     WEAR shoes
#     CARRY bag
#     LEAVE room
# END
# ![image.png](attachment:61ea4458-e99f-4b7a-b812-732df5850915.png)

# %% [markdown]
# BEGIN
#     INPUT name1
#     INPUT name2
#
#     temp ← name1
#     name1 ← name2
#     name2 ← temp
#
#     OUTPUT name1
#     OUTPUT name2
# END
