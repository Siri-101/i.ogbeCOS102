# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk
import csv

with open('C:/Users/New/Downloads/GIG-logistics(in).csv', mode='r') as file:
    reader = csv.DictReader(file)
    employee_count = 0
    employee = []
    profile = []
    for row in reader:
        employee.append([row['Name'], row['Department']])
        employee_count += 1

def welcomeMessage(username, dept_list):
# Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This is Python GUI with Tkinter")
    label_4 = tk.Label(window, text="These are the other members of your department: ")
    label_2.pack()
    for name in dept_list:
        label_3 = tk.Label(window, text=f"{name}")
        label_3.pack()

    
    # Run the Tkinter event loop
    root.mainloop()


def submit():
    username = username_entry.get()
    password = password_entry.get()
    name_in_list = ""
    department = ""
    dept_list = []
    for name in employee:
        if username == name[0]:
            department = name[1]
            name_in_list = name[0]
               
    for name in employee:
        if name[1] == department:
            dept_list.append(name[0])

    welcomeMessage(username, dept_list )

# %%
# Create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("500x200")

# Create username label and entry
username_label = tk. Label(root, text="Username:")
username_label.pack()
username_entry = tk. Entry(root)
username_entry.pack()

# Create password label and entry
password_label = tk. Label(root, text="Department:")
password_label.pack()
password_entry = tk. Entry(root)
password_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
