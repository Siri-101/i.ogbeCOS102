# %%
principal = 350000
rate = 40
time_in_years = 3
n = 1

rate_to_fraction = 40/100
s_interest = principal* (1 + rate_to_fraction)
principal_amount = principal + s_interest
c_interest = principal * (1 + (rate_to_fraction/n)**(n*time_in_years))
compound_amount = principal + c_interest
print(principal_amount)
print(s_interest)
print(compound_amount)
print(c_interest)
# Out:
# 840000.0
# 489999.99999999994
# 722400.0
# 372400.0
